# %% [markdown]
# # Some very basic things in R
#
# ## work with numbers, variables vectors
# Numbers:
#
# `5+5`
#
# `5^5`
#
# Variables:
#
# `a<-600`
#
# `b<-7`
#
# `a+b`
#
# `a^b`
#
# Vectors:
#
# `1:10`
#
# `b:a`
#
# Built-in mathematical functions:
#
# `sqrt(5)`
#
# `sqrt(a)`
#
# `mean(b:a)`

# %% [markdown]
# ## Types of objects
#
# Vector:
#
# `new_vec<-c(1,4,5,"A",1/5, "Random text")`
#
# Array:
#
# `new_mat<-matrix(new_vec,nrow=2)`
#
# List:
#
# `new_list<-list(new_vec,new_mat)`

# %% [markdown]
# ## Custom functions
#
# Simple example:
# `my_function<-function(input) { sum(input)*50 } `
#
#
# An example: multiply value with a vector, and check if values are positive
# ```
# myfunc<-function(input1, input2) {
#   r1<-input1*input2
#   for (j in (1:length(r1))) {
#     if (r1[j]<0) {r1[j]<-NA}
#     }
#     return(r1)
#   }
#
# i1<-sample(seq(50:149),11)
# i2<-rnorm(n=100,mean=50,sd=33)
#
# myresult<-lapply(i1,myfunc,input2=i2)
# ```
# What is happening?

# %% [markdown]
# ## Processing data - data.frames
# Read and write a table:
# ```
# setwd("~/notebooks/basics/data/")
#
# testfile<-read.table('fileA.txt',as.is=T,sep="\t",header=T)
# head(testfile)
# nrow(testfile)
#
# write.table(testfile, 'fileG.txt ',sep="\t",row.names=F,col.names=F,quote=F)
#
# ```
# Tables and what they mean.
#
# Build your own:
# ```
# newtab<-data.frame(first=b:a,second=a:b)
# ```
#
# ```
# head(testfile)
# nrow(testfile)
# table(testfile[,2])
# table(testfile$fruit)
#
# mean(as.numeric(testfile[,3]))
# as.numeric(testfile[,3])>50
# table(as.numeric(testfile[,3])>50)
# ```

# %% [markdown]
# ## Some plotting
# ```
# plot(myresult[[1]],i2)
#
# hist(i2)
#
# barplot(i1,col="red")
# ```
#
# And with apples and oranges:
#
# ```
# newdf<-as.matrix(table(testfile$fruit))
#
# barplot(newdf,beside=T,names.arg=rownames(newdf),las=2)
#
# newdf2<-rbind(newdf[which(rownames(newdf)%in%c("apple","orange","pear")),,drop=F],sum(newdf[-which(rownames(newdf)%in%c("apple","orange","pear")),1]))
# rownames(newdf2)[4]<-"other"
#
# barplot(newdf2,beside=T,names.arg=rownames(newdf2),las=2)
#
# ```
